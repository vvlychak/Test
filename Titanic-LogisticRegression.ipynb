# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
titanic = pd.read_csv('../input/titanic/train.csv')
titanic.head()

# %%
X = titanic.drop(['PassengerId', 'Survived', 'Name', 'Ticket', 'Cabin'], axis=1)
y = titanic.Survived
X

# %%
X = pd.get_dummies(X)
X

# %%
X.isnull().sum()

# %%
X = X.fillna({'Age': X.Age.median()})
X.isnull().sum()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 42)

# %%
logreg = LogisticRegression()

# %%
logreg.fit(X_train, y_train)

# %%
logreg.score(X_train, y_train)

# %%
logreg.score(X_test, y_test)

# %%
test = pd.read_csv('../input/titanic/test.csv')
test.head()

# %%
test = test.drop(['PassengerId', 'Name', 'Ticket', 'Cabin'], axis=1)
test.head()

# %%
test = pd.get_dummies(test)
test.head()

# %%
test.isnull().sum()

# %%
test = test.fillna({'Age': test.Age.median(), 'Fare': test.Fare.median()})
test.isnull().sum()

# %%
result = pd.DataFrame()
result['PassengerId'] = pd.read_csv('../input/titanic/test.csv')['PassengerId']
result['Survived'] = logreg.predict(test)
result.head()

# %%
result.to_csv('./result9.csv', index=False)
